# %%
import os
import pandas as pd
import numpy as np 
Data = pd.read_csv('cars_sampled.csv')
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50001 entries, 0 to 50000
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50001 non-null  object
#  1   name                 50001 non-null  object
#  2   seller               50001 non-null  object
#  3   offerType            50001 non-null  object
#  4   price                50001 non-null  int64
#  5   abtest               50001 non-null  object
#  6   vehicleType          44813 non-null  object
#  7   yearOfRegistration   50001 non-null  int64
#  8   gearbox              47177 non-null  object
#  9   powerPS              50001 non-null  int64
#  10  model                47243 non-null  object
#  11  kilometer            50001 non-null  int64
#  12  monthOfRegistration  50001 non-null  int64
#  13  fuelType             45498 non-null  object
#  14  brand                50001 non-null  object
# ...

# %%
Data.head(5)
# Out:
#         dateCrawled                                               name  \
# 0  30/03/2016 13:51                                       Zu_verkaufen
# 1     7/3/2016 9:54                             Volvo_XC90_2.4D_Summum
# 2     1/4/2016 0:57                                  Volkswagen_Touran
# 3  19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4  16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
#
#     seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0  private     offer   4450     test   limousine                2003
# 1  private     offer  13299  control         suv                2005
# 2  private     offer   3200     test         bus                2003
# 3  private     offer   4500  control   small car                2006
# 4  private     offer  18750     test         suv                2008
#
#      gearbox  powerPS     model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
Data.describe()
# Out:
#               price  yearOfRegistration       powerPS      kilometer  \
# count  5.000100e+04        50001.000000  50001.000000   50001.000000
# mean   6.559865e+03         2005.544229    116.496130  125613.687726
# std    8.581847e+04          122.991832    230.567709   40205.234483
# min    0.000000e+00         1000.000000      0.000000    5000.000000
# 25%    1.150000e+03         1999.000000     69.000000  125000.000000
# 50%    2.950000e+03         2003.000000    105.000000  150000.000000
# 75%    7.190000e+03         2008.000000    150.000000  150000.000000
# max    1.234568e+07         9999.000000  19312.000000  150000.000000
#
#        monthOfRegistration    postalCode
# count         50001.000000  50001.000000
# mean              5.743725  50775.216696
# std               3.711345  25743.701933
# min               0.000000   1067.000000
# 25%               3.000000  30559.000000
# 50%               6.000000  49504.000000
# 75%               9.000000  71404.000000
# ...

# %%
# Data['dateCrawled'] = Data['dateCrawled'].replace(Data['name'])

# %%
Data.head(-5)
# Out:
#             dateCrawled                                               name  \
# 0      30/03/2016 13:51                                       Zu_verkaufen
# 1         7/3/2016 9:54                             Volvo_XC90_2.4D_Summum
# 2         1/4/2016 0:57                                  Volkswagen_Touran
# 3      19/03/2016 17:50                       Seat_Ibiza_1.4_16V_Reference
# 4      16/03/2016 14:51  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...
# ...                 ...                                                ...
# 49991   10/3/2016 23:36                                        BMW_X3_3.0i
# 49992  14/03/2016 13:57                         Opel_Astra_2.0_DI_Elegance
# 49993  14/03/2016 11:37       Renault_Clio_mit_Servolenkung_und_neuem_TÜV!
# 49994     9/3/2016 1:36                                        Porsche_993
# 49995  23/03/2016 21:45  Opel_Astra_G_Caravan__Tuev_2/2018__Scheckheft_...
#
# ...

# %%
j = ['dateCrawled','name','seller','offerType','price','abtest','vehicleType','yearOfRegistration','gearbox','powerPS','model','kilometer','monthOfRegistration','fuelType','brand','notRepairedDamage','dateCreated','postalCode','lastSeen']
for i in j:
    # it will give the frequency of each category
    a = pd.crosstab(index=Data[i],columns='count',dropna=True)
   # j+=1
    print(a)
# Out:
# col_0          count
# dateCrawled
# 1/4/2016 0:25      1
# 1/4/2016 0:32      2
# 1/4/2016 0:36      6
# 1/4/2016 0:37      2
# 1/4/2016 0:39      1
# ...              ...
# 9/3/2016 9:54      6
# 9/3/2016 9:55      3
# 9/3/2016 9:56      8
# 9/3/2016 9:57      6
# 9/3/2016 9:58      1
#
# [12039 rows x 1 columns]
# col_0                                               count
# name
# !!!!!!!!__Skoda_Superb_2.0_TDI_DSG__Elegance__!...      1
# !!!!!!BMW_325_COUPE_TOP_ZUSTAND_ANSCHAUEN_LOHNT...      1
# !!!!!_Mittwoch_Angebot_!!!!_Nissan_Micra_1.2_Ac...      1
# !!!!Gepflegert_Fiat_Punto_1_Hand_!!!!!                  1
# !!!!PREISSENKUNG!!!!____VW_GOLF_4_1.4_75_PS_ALU...      1
# ...                                                   ...
# ~~?Sehr_gepfleges_Fiesta_§Sparsam§_wenig_Kilom...      1
# _Mercedes_Benz_E200_Kompressor___Garage___Sc...      2
# Nissan_almera_TÜV_2017_tuning_Hifi/Sportauspuf...      1
# ğSommerautoĞ_Opel_Astra_F_Cabrio_"Bertone_Edition"      1
# ...

# %%
Data['name'],Data['dateCrawled'] = Data['dateCrawled'],Data['name']
Data.rename(columns={'dateCrawled':'Name','name':'dateCrawled'},inplace=True)

# %%
Data.head()
# Out:
#                                                 Name       dateCrawled  \
# 0                                       Zu_verkaufen  30/03/2016 13:51
# 1                             Volvo_XC90_2.4D_Summum     7/3/2016 9:54
# 2                                  Volkswagen_Touran     1/4/2016 0:57
# 3                       Seat_Ibiza_1.4_16V_Reference  19/03/2016 17:50
# 4  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...  16/03/2016 14:51
#
#     seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0  private     offer   4450     test   limousine                2003
# 1  private     offer  13299  control         suv                2005
# 2  private     offer   3200     test         bus                2003
# 3  private     offer   4500  control   small car                2006
# 4  private     offer  18750     test         suv                2008
#
#      gearbox  powerPS     model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
pd.crosstab(index=Data['Name'],columns='count',dropna=True)
# Out:
# col_0                                               count
# Name
# !!!!!!!!__Skoda_Superb_2.0_TDI_DSG__Elegance__!...      1
# !!!!!!BMW_325_COUPE_TOP_ZUSTAND_ANSCHAUEN_LOHNT...      1
# !!!!!_Mittwoch_Angebot_!!!!_Nissan_Micra_1.2_Ac...      1
# !!!!Gepflegert_Fiat_Punto_1_Hand_!!!!!                  1
# !!!!PREISSENKUNG!!!!____VW_GOLF_4_1.4_75_PS_ALU...      1
# ...                                                   ...
# ~~?Sehr_gepfleges_Fiesta_§Sparsam§_wenig_Kilom...      1
# _Mercedes_Benz_E200_Kompressor___Garage___Sc...      2
# Nissan_almera_TÜV_2017_tuning_Hifi/Sportauspuf...      1
# ğSommerautoĞ_Opel_Astra_F_Cabrio_"Bertone_Edition"      1
# ğ_gepflegter_VW_Passat_3c_TDI_abzugeben__!              1
#
# [38766 rows x 1 columns]

# %%
Data.head(5)
# Out:
#                                                 Name       dateCrawled  \
# 0                                       Zu_verkaufen  30/03/2016 13:51
# 1                             Volvo_XC90_2.4D_Summum     7/3/2016 9:54
# 2                                  Volkswagen_Touran     1/4/2016 0:57
# 3                       Seat_Ibiza_1.4_16V_Reference  19/03/2016 17:50
# 4  Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...  16/03/2016 14:51
#
#     seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 0  private     offer   4450     test   limousine                2003
# 1  private     offer  13299  control         suv                2005
# 2  private     offer   3200     test         bus                2003
# 3  private     offer   4500  control   small car                2006
# 4  private     offer  18750     test         suv                2008
#
#      gearbox  powerPS     model  kilometer  monthOfRegistration fuelType  \
# ...

# %%
# Data.style.applymap(lambda x : 'text-align:left;',subset=['Name'])

# %%
Data.rename(columns={'seller':'Type of Seller','offerType':'Type Of Offer','vehicleType':'Type Of Vehicle','yearOfRegistration':"Year Of Registration",'gearbox': 'Type Of GearBox','monthOfRegistration':'Month Of Registration'})
# Out:
#                                                     Name       dateCrawled  \
# 0                                           Zu_verkaufen  30/03/2016 13:51
# 1                                 Volvo_XC90_2.4D_Summum     7/3/2016 9:54
# 2                                      Volkswagen_Touran     1/4/2016 0:57
# 3                           Seat_Ibiza_1.4_16V_Reference  19/03/2016 17:50
# 4      Volvo_XC90_D5_Aut._RDesign_R_Design_AWD_GSHD_S...  16/03/2016 14:51
# ...                                                  ...               ...
# 49996                               Suche_VW_T5_Multivan    3/4/2016 15:48
# 49997  Suche_einen_originalen_VW_Golf_2_Fire_and_Ice_G60  27/03/2016 14:55
# 49998  [SUCHE]_BMW_e46_Coupe_330ci_M_Paket_Facelift__...  14/03/2016 18:51
# 49999        Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten  15/03/2016 18:06
# 50000                    Chevrolet_Matiz_1.Hd_TÜV11/2017   22/03/2016 9:54
#
# ...
